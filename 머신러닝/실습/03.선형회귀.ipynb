# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression, SGDRegressor

import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
carDF = pd.read_csv('data/cars.csv', index_col='Unnamed: 0')
carDF
# Out:
#     speed  dist
# 1       4     2
# 2       4    10
# 3       7     4
# 4       7    22
# 5       8    16
# 6       9    10
# 7      10    18
# 8      10    26
# 9      10    34
# 10     11    17
# 11     11    28
# 12     12    14
# 13     12    20
# 14     12    24
# 15     12    28
# 16     13    26
# 17     13    34
# 18     13    34
# 19     13    46
# 20     14    26
# 21     14    36
# 22     14    60
# 23     14    80
# 24     15    20
# 25     15    26
# 26     15    54
# 27     16    32
# 28     16    40
# 29     17    32
# 30     17    40
# 31     17    50
# 32     18    42
# 33     18    56
# 34     18    76
# 35     18    84
# 36     19    36
# 37     19    46
# 38     19    68
# 39     20    32
# 40     20    48
# 41     20    52
# 42     20    56
# 43     20    64
# 44     22    66
# 45     23    54
# 46     24    70
# 47     24    92
# 48     24    93
# 49     24   120
# 50     25    85

# %%
carDF.shape
# Out:
# (50, 2)

# %%
x = carDF[['speed']].values
y = carDF[['dist']].values

# %%
y
# Out:
# array([[  2],
#        [ 10],
#        [  4],
#        [ 22],
#        [ 16],
#        [ 10],
#        [ 18],
#        [ 26],
#        [ 34],
#        [ 17],
#        [ 28],
#        [ 14],
#        [ 20],
#        [ 24],
#        [ 28],
#        [ 26],
#        [ 34],
#        [ 34],
#        [ 46],
#        [ 26],
#        [ 36],
#        [ 60],
#        [ 80],
#        [ 20],
#        [ 26],
#        [ 54],
#        [ 32],
#        [ 40],
#        [ 32],
#        [ 40],
#        [ 50],
#        [ 42],
#        [ 56],
#        [ 76],
#        [ 84],
#        [ 36],
#        [ 46],
#        [ 68],
#        [ 32],
#        [ 48],
#        [ 52],
#        [ 56],
#        [ 64],
#        [ 66],
#        [ 54],
#        [ 70],
#        [ 92],
#        [ 93],
#        [120],
#        [ 85]])

# %%
plt.xlabel('자동차속도')
plt.ylabel('제동거리')
plt.scatter( x, y)
plt.show()

# %% [markdown]
# ## 회귀공식을 이용

# %%
model = LinearRegression()
model.fit( x, y) #특성데이터, 라벨 (행렬로)
# Out:
# LinearRegression()

# %%
print('기울기', model.coef_)
print('절편', model.intercept_)
# Out:
# 기울기 [[3.93240876]]
# 절편 [-17.57909489]

# %%
10*float(model.coef_) + float(model.intercept_ )
# Out:
# C:\Users\승학산-강사pc\AppData\Local\Temp\ipykernel_9556\671137123.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   10*float(model.coef_) + float(model.intercept_ )
# 21.744992700729917

# %%
model.predict( [[10]] ) # 행렬로
# Out:
# array([[21.7449927]])

# %%
model.predict([ [10],[15] ] )
# Out:
# array([[21.7449927],
#        [41.4070365]])

# %%
class MyLinear:
    def __init__(self):
        self.coef_ = None
        self.intercept_= None

    def fit(self, x, y):
        self.coef_= np.sum((x-x.mean())*(y-y.mean()))/np.sum((x-x.mean())**2)
        self.intercept_= y.mean()- self.coef_*x.mean()
    def predict( self, x):
        return self.coef_*x + self.intercept_
x = np.array( [1,2,3,4,5] )
y = np.array( [3,5,7,9,11])
mymodel = MyLinear()
mymodel.fit( x, y)
print( mymodel.coef_, mymodel.intercept_)
print( mymodel.predict(7))
# Out:
# 2.0 1.0
# 15.0

# %%
class Test:
    def __init__(self,a,b):
        self.a = a
        self.b = b

    def show(self):
        print('a=',self.a, 'b=',self.b )

tt = Test(10,20)
# tt.__init__(10,20)
tt.show()
print( tt.a, tt.b)
# Out:
# a= 10 b= 20
# 10 20
