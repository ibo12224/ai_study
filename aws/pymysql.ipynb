# %%
import pymysql

# 1. 데이터베이스 연결 설정
connection = pymysql.connect(
    host='database-1.cjh1vqjhlwr8.ap-northeast-2.rds.amazonaws.com',
    user='admin',      # 본인의 DB 계정
    password='pass',  # 본인의 DB 비밀번호
    database='test',            # 데이터베이스 이름
)

try:
    with connection.cursor() as cursor:
        # 2. SQL 쿼리 작성
        sql = "INSERT INTO student (name, age, birth) VALUES (%s, %s, %s)"
        
        # 3. 추가할 데이터 (튜플 형태)
        new_student = ('홍길동', 20, '2004-05-15')
        
        # 4. 쿼리 실행
        cursor.execute(sql, new_student)
        
    # 5. 데이터 변경사항 저장 (Commit)
    connection.commit()
    print("데이터가 성공적으로 추가되었습니다.")

except Exception as e:
    # 에러 발생 시 롤백
    connection.rollback()
    print(f"에러 발생: {e}")

finally:
    # 6. 연결 종료
    connection.close()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\Dell5371\AppData\Local\Programs\Python\Python310\lib\site-packages\pymysql\connections.py:661, in Connection.connect(self, sock)
#     660 try:
# --> 661     sock = socket.create_connection(
#     662         (self.host, self.port), self.connect_timeout, **kwargs
#     663     )
#     664     break
#
# File c:\Users\Dell5371\AppData\Local\Programs\Python\Python310\lib\socket.py:824, in create_connection(address, timeout, source_address)
#     823 err = None
# --> 824 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     825     af, socktype, proto, canonname, sa = res
#
# File c:\Users\Dell5371\AppData\Local\Programs\Python\Python310\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pymysql
#       3 # 1. 데이터베이스 연결 설정
# ----> 4 connection = pymysql.connect(
#       5     host='database-1.cjh1vqjhlwr8.ap-northeast-2.rds.amazonaws.com',
#       6     user='admin',      # 본인의 DB 계정
#       7     password='pass',  # 본인의 DB 비밀번호
#       8     database='test',            # 데이터베이스 이름
#       9 )
#      11 try:
#      12     with connection.cursor() as cursor:
#      13         # 2. SQL 쿼리 작성
#
# File c:\Users\Dell5371\AppData\Local\Programs\Python\Python310\lib\site-packages\pymysql\connections.py:365, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_key_password, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     363     self._sock = None
#     364 else:
# --> 365     self.connect()
#
# File c:\Users\Dell5371\AppData\Local\Programs\Python\Python310\lib\site-packages\pymysql\connections.py:723, in Connection.connect(self, sock)
#     721     if DEBUG:
#     722         print(exc.traceback)
# --> 723     raise exc
#     725 # If e is neither DatabaseError or IOError, It's a bug.
#     726 # But raising AssertionError hides original error.
#     727 # So just reraise it.
#     728 raise
#
# OperationalError: (2003, "Can't connect to MySQL server on 'database-1.cjh1vqjhlwr8.ap-northeast-2.rds.amazonaws.com' ([Errno 11001] getaddrinfo failed)")
