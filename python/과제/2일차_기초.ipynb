# %%
dic={"메로나":1000,
     "폴라포":1200,
     "빵빠레":1800}
print(dic)
# Out:
# {'메로나': 1000, '폴라포': 1200, '빵빠레': 1800}

# %%
dic.update({"죠스바":1200,"월드콘":1500})
print(dic)
# Out:
# {'메로나': 1000, '폴라포': 1200, '빵빠레': 1800, '죠스바': 1200, '월드콘': 1500}

# %%
#print(3=>4)
3>=4
#부등호가 잘못된 순서로 배치됨
# Out:
# False

# %%
s=input("입력:")
print(s+s)
# Out:
# 123123

# %%
fruit={"봄":"딸기","여름": "토마토","가을":"사과"}
fav=input("제가좋아하는계절은: ")
if fav in fruit:
    print("정답입니다.")
else:
    print("오답입니다.")
# Out:
# 오답입니다.

# %%
s=int(input("학점입력"))
sc=""
if s>80:
    sc="A"
elif s>60:
    sc="B"
elif s>40:
    sc="C"
elif s>20:
    sc="D"
elif s>0:
    sc="E"
print(sc)
# Out:
# C

# %%
list=["김밥","라면","튀김"]
print(f"리스트 = {list}")
for i in list:
    print("오늘의 메뉴: "+i)
# Out:
# 리스트 = ['김밥', '라면', '튀김']
# 오늘의 메뉴: 김밥
# 오늘의 메뉴: 라면
# 오늘의 메뉴: 튀김

# %%
list=["SK하이닉스","삼성전자","LG전자"]
for i in list:
    print("저장된 문자열 길이",len(i))
# Out:
# 저장된 문자열 길이 6
# 저장된 문자열 길이 4
# 저장된 문자열 길이 4

# %%
list=[3,100,23,44,9]
for i in list:
    if i%3==0:
        print(i)
# Out:
# 3
# 9

# %%
list=["I","study","python","language","!"]
for i in list:
    if len(i)>2:
        print(i)
# Out:
# study
# python
# language
