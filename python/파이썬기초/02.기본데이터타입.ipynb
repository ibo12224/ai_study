# %% [markdown]
# # 2. 데이터타입

# %% [markdown]
# ### 1. 정수

# %%
a = 10
print(a)
b=20
print(b)
# Out:
# 10
# 20

# %% [markdown]
# ### 2. 실수

# %%
f=3.14
f1=3.141592e3
print(f)
print(type(f))
print(f1)
print(type(f1))
# Out:
# 3.14
# <class 'float'>
# 3141.592
# <class 'float'>

# %% [markdown]
# ### 3. bool

# %%
a=True
print(a)
# Out:
# True

# %% [markdown]
# ### 4. 문자열, 리스트, 튜플 세트, 딕셔너리

# %%
s1="abcdef"
s2="abcdef"
s3="""abcdef"""
s4='''abcdef'''

print(s1)
print(s2)
print(s3)
print(s4)
# Out:
# abcdef
# abcdef
# abcdef
# abcdef
