# %%
print("신씨가 소리질렀다. \"도둑이야\"",)
# Out:
# 신씨가 소리질렀다. "도둑이애"

# %%
시가총액=298
현재가=50000
PER=15.79
print(시가총액)
print(현재가)
print(PER)
# Out:
# 298

# %%
license_plate="24 가 2210"
license_plate[-5::]
# Out:
# ' 2210'

# %%
string="홀짝홀짝홀짝"
string[::2]
# Out:
# '홀홀홀'

# %%
a3='010-1111-2222'
print(a3.replace('-',' '))
# Out:
# 010 1111 2222

# %%
url="http://sharebook.kr"
print(url[-2:])
# Out:
# kr
