# %%
class Test:
    st = 100 # static 멤버(객체생성X), 클래스변수
    def __init__(self):
        self.a = 0 # instance변수( 반드시 객체 생성필요)
        self.b = 0 # instance변수( 반드시 객체 생성필요)
    def setData(self, x,y): 
        self.a = x
        self.b = y
    def show(self):
        print( self.a, self.b)

print( Test.st)
obj = Test()
# Out:
# 100
