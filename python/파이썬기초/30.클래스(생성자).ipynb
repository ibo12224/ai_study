# %%
class Test:
    def __init__(self):
        self.a = 0 
        self.b = 0
    def setData(self, x,y): 
        self.a = x
        self.b = y
    def show(self):
        print( self.a, self.b)

obj = Test()

# %%
class Test:
    def __init__(self,a,b):
        self.a = a 
        self.b = b 
    def setData(self, x,y): 
        self.a = x
        self.b = y
    def show(self):
        print( self.a, self.b)

obj = Test( 10, 20)
# obj.__init__( obj, 10, 20)
obj.show() # obj.show(obj )
obj.setData(100,200) #obj.setData(obj,100,200)
obj.show() # obj.show(obj )
# Out:
# 10 20
# 100 200

# %%
class Test:
    def __init__(self,a=0,b=0):
        self.a = a 
        self.b = b 
    def setData(self, x,y): 
        self.a = x
        self.b = y
    def show(self):
        print( self.a, self.b)
#obj = Test( 10,20)
# obj.__init__( obj,10,20)
#obj = Test( )
# obj.__init__( obj)
obj = Test( b=100)
# obj.__init__( obj,b=100)
obj.show() # obj.show(obj )
obj.setData(100,200) #obj.setData(obj,100,200)
obj.show() # obj.show(obj )
# Out:
# 0 100
# 100 200
