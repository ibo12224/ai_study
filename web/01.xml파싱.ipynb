# %% [markdown]
# ## 대표적인 데이터유형
# - csv, (excel)
# - json: (일반적으로 openapi)
# - xml:(일반적으로 openapi)
# - html

# %% [markdown]
# ## 엘리먼트 값 가져오는 방법
# 1. selector( css):beautifulsoup
# 2. xpath( selenium, scrapy)

# %% [markdown]
# ## 대표적인 crawler
# - beautifulsoup:문법이 쉬움
# - selenium: 브라우저 직접제어
# - scrapy: 최강의 crawler

# %% [markdown]
# ```javascript
# # json array( 딕셔너리 리스트)
# [ {'singer':'singer1','title':'title1'},
#  {'singer':'singer1','title':'title1'}
# ]

# %%
# %pip install bs4
# %pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
fp=open('data/song.xml')
kpop=BeautifulSoup(fp,"html.parser")
kpop
# Out:
# <kpop>
# <slist>
# <song album="album1">
# <singer>singer1</singer>
# <title>title1</title>
# </song>
# <song album="album2">
# <singer>singer2</singer>
# <title>title2</title>
# </song>
# <song album="album3">
# <singer>singer3</singer>
# <title>title3</title>
# </song>
# </slist>
# </kpop>

# %%
#kpop.slist

# %%
kpop.find('slist')
# Out:
# <slist>
# <song album="album1">
# <singer>singer1</singer>
# <title>title1</title>
# </song>
# <song album="album2">
# <singer>singer2</singer>
# <title>title2</title>
# </song>
# <song album="album3">
# <singer>singer3</singer>
# <title>title3</title>
# </song>
# </slist>

# %%
kpop.find('song',{'album':'album2'})
# Out:
# <song album="album2">
# <singer>singer2</singer>
# <title>title2</title>
# </song>

# %%
kpop.find_all('song')
# Out:
# [<song album="album1">
#  <singer>singer1</singer>
#  <title>title1</title>
#  </song>,
#  <song album="album2">
#  <singer>singer2</singer>
#  <title>title2</title>
#  </song>,
#  <song album="album3">
#  <singer>singer3</singer>
#  <title>title3</title>
#  </song>]

# %%
for song in kpop.find_all('song'):
    print(song)
    print('===========')
# Out:
# <song album="album1">
# <singer>singer1</singer>
# <title>title1</title>
# </song>
# ...
# <song album="album2">
# <singer>singer2</singer>
# <title>title2</title>
# </song>
# ...
# <song album="album3">
# <singer>singer3</singer>
# <title>title3</title>
# </song>
# ...

# %%
fp=open('data/food.xml')
food=BeautifulSoup(fp,"html.parser")
food
# Out:
# C:\Users\Dell5371\AppData\Local\Temp\ipykernel_18032\3100200398.py:2: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   food=BeautifulSoup(fp,"html.parser")
# <?xml version="1.0" encoding="UTF-8"?>
# <breakfast_menu>
# <food>
# <name>Belgian Waffles</name>
# <price>$5.95</price>
# <description>
# ...

# %%
for fd in food.find_all('food'):
    print(fd.find('name').string,fd.price.string)
    print('-=-')
# Out:
# Belgian Waffles $5.95
# -=-
# Strawberry Belgian Waffles $7.95
# -=-
# Berry-Berry Belgian Waffles $8.95
# -=-
# French Toast $4.50
# -=-
# Homestyle Breakfast $6.95
# -=-

# %%
import requests 
url='https://www.yna.co.kr/rss/news.xml'
print()
response=requests.get(url)
response
# rss=BeautifulSoup(response.content,"html.parser")
# rss
# Out:
# <Response [200]>

# %% [markdown]
# item 엘리먼트의 title(기사제목), description(기사간단내용)
#
# 기사제목:
# 기사내용:
# =================
# 기사제목:
# 기사내용:
#
# ...

# %%
for news in rss.find_all('item'):
    print('기사제목:'+news.find('title').string)
    print('기사내용:'+news.find('description').string)
    print('=======================')
# Out:
# 기사제목:금정산 국립공원공단 임시사무소 설치 위치는 어디로
# 기사내용:(부산=연합뉴스) 차근호 기자 = 내년 3월부터 국립공원으로 지정되는 부산 금정산을 관리하게 될 국립공원관리단 임시사무소 위치가 이르면 이달 말...
# ...
# 기사제목:울주군 '생명지킴이 헤어숍' 활동 성과…정신건강 위험군 발굴
# 기사내용:(울산=연합뉴스) 장영은 기자 = 울산 울주군정신건강복지센터는 20일 &apos;생명지킴이 헤어숍&apos; 운영 성과 공유 평가회를 열어 모범적인 활동을 펼친 ...
# ...
# 기사제목:KLPGA 안소현, 취약 계층 난방비 지원 자선 골프대회 개최
# 기사내용:(서울=연합뉴스) 김동찬 기자 = 안소현이 취약 계층 난방비 지원을 위한 자선 골프 대회를 4년 연속 열었다.
# ...
# 기사제목:무인도 좌초 여객선 부상 승객 30명 중 26명 퇴원…"중상 없어"
# 기사내용:(목포=연합뉴스) 정다움 기자 = 2만6천여t급 대형 카페리 여객선 퀸제누비아2호가 전남 신안군 해상 무인도에 좌초하는 사고로 다친 탑승객 대다...
# ...
# 기사제목:현대트랜시스, 3년연속 국가품질경영대회 '품질경쟁력 우수기업'
# 기사내용:(서울=연합뉴스) 임성호 기자 = 현대트랜시스가 19일 서울 코엑스 오디토리움에서 열린 &apos;제51회 국가품질경영대회&apos;에서 3년 연속 &apos;품질경쟁력 ...
# ...
# 기사제목:관악구, 제설 인프라 확충…도로열선 늘리고 블랙아이스 예방
# 기사내용:(서울=연합뉴스) 정준영 기자 = 관악구(구청장 박준희)는 폭설 등 겨울철 재난 상황에 대비해 내년 3월 15일까지를 동절기 제설대책 기간으로 ...
# ...
# 기사제목:옥천군 민선8기 공약 추진율 85%…"45건 완료·35건 진행중"
# 기사내용:(옥천=연합뉴스) 박병기 기자 = 충북 옥천군은 민선 8기 황규철 군수의 공약 추진율이 85%를 기록 중이라고 20일 밝혔다.
#
# ...
# 기사제목:삼성전자, '테크 콘퍼런스 2025' 개최…AI 연구성과 공개
# ...
