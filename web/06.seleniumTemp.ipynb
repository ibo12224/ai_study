# %% [markdown]
# ### 주요 메소드
# ```python
#
# - driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div/div[3]/form/fieldset/button/span[2]')
# xpath 로 접근
#
# - driver.find_element_by_class_name('ico_search_submit')
#
# class 속성으로 접근
#
# - driver.find_element_by_id('ke_kbd_btn')
#
# id 속성으로 접근
#
# - driver.find_element_by_link_text('회원가입')
#
# 링크가 달려 있는 텍스트로 접근
#
# - driver.find_element_by_css_selector('#account > div > a')
#
# css 셀렉터로 접근
#
# - driver.find_element_by_name('join')
#
# name 속성으로 접근
#
# - driver.find_element_by_partial_link_text('가입')
#
# 링크가 달려 있는 엘레먼트에 텍스트 일부만 적어서 해당 엘레먼트에 접근
#
# - driver.find_element_by_tag_name('input')
#
# 태그 이름으로 접근
#
# - driver.find_element_by_tag_name('input').find_element_by_tag_name('a')
#
# input 태그 하위태그인 a 태그에 접근
#
# - driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div/div[3]/form/fieldset/button/span[2]').find_element_by_name('join')
#
# xpath 로 접근한 엘레먼트의 안에 join 이라는 속성을 가진 tag 엘레먼트에 접근

# %%
from selenium.webdriver.common.by import By

driver.find_element(By.XPATH, '//button[text()="Some text"]') 
driver.find_element(By.XPATH, '//button') 
driver.find_element(By.ID, 'loginForm') 
driver.find_element(By.LINK_TEXT, 'Continue') 
driver.find_element(By.PARTIAL_LINK_TEXT, 'Conti') 
driver.find_element(By.NAME, 'username') 
driver.find_element(By.TAG_NAME, 'h1') 
driver.find_element(By.CLASS_NAME, 'content') 
driver.find_element(By.CSS_SELECTOR, 'p.content')

driver.find_elements(By.ID, 'loginForm') 
driver.find_elements(By.CLASS_NAME, 'content')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from selenium.webdriver.common.by import By
# ----> 3 driver.find_element(By.XPATH, '//button[text()="Some text"]')
#       4 driver.find_element(By.XPATH, '//button')
#       5 driver.find_element(By.ID, 'loginForm')
#
# NameError: name 'driver' is not defined

# %%
# %pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.38.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.32.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.10.5 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from selenium) (2025.10.5)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\dell5371\appdata\roaming\python\python310\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Collecting sortedcontainers (from trio<1.0,>=0.31.0->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.0.0)
# Requirement already satisfied: exceptiongroup in c:\users\dell5371\appdata\roaming\python\python310\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3.0,>=2.5.0->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pycparser in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.23)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.38.0-py3-none-any.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ------------------------------------ --- 8.9/9.7 MB 50.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 43.1 MB/s  0:00:00
# Downloading trio-0.32.0-py3-none-any.whl (512 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, wsproto, pysocks, outcome, trio, trio-websocket, selenium
#
#    ----------- ---------------------------- 2/7 [pysocks]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------------- 7/7 [selenium]
#
# Successfully installed outcome-1.3.0.post0 pysocks-1.7.1 selenium-4.38.0 sortedcontainers-2.4.0 trio-0.32.0 trio-websocket-0.12.2 wsproto-1.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from webdriver-manager) (2.32.5)
# Collecting python-dotenv (from webdriver-manager)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: packaging in c:\users\dell5371\appdata\roaming\python\python310\site-packages (from webdriver-manager) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (2025.10.5)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: python-dotenv, webdriver-manager
#
#    -------------------- ------------------- 1/2 [webdriver-manager]
#    ---------------------------------------- 2/2 [webdriver-manager]
#
# Successfully installed python-dotenv-1.2.1 webdriver-manager-4.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

def set_chrome_driver():
    chrome_options = webdriver.ChromeOptions()
#     chrome_options.add_argument('headless')
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), 
                              options=chrome_options)
    return driver

# %%
driver = set_chrome_driver()

# %%
murl="https://www.menupan.com/restaurant/bestrest/bestrest.asp?pt=rt&areacode=bs205"
driver.get(murl)

# %%
driver.current_url
# Out:
# 'https://www.menupan.com/restaurant/bestrest/bestrest.asp?pt=rt&areacode=bs205'

# %%
aList=driver.find_elements(By.CSS_SELECTOR,'.restName > a')
for a in aList:
    print( a.get_attribute('outerHTML'))
    print(a.text)
    print('------------------------------------')
# Out:
# <a href="/restaurant/onepage.asp?acode=H602082" target="_blank">부산돼지국밥</a>
# 부산돼지국밥
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=B600008" target="_blank">호찐빵</a>
# 호찐빵
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=J600539" target="_blank">히노아지 센텀점</a>
# 히노아지 센텀점
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=B600043" target="_blank">상국이네</a>
# 상국이네
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=D600801" target="_blank">카페윤</a>
# 카페윤
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=G600035" target="_blank">옵스 마린시티점</a>
# 옵스 마린시티점
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H600631" target="_blank">기장곰장어</a>
# 기장곰장어
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H601524" target="_blank">오반장</a>
# 오반장
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H601497" target="_blank">뜰아래채</a>
# 뜰아래채
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H601506" target="_blank">일번지 자갈치 산곰장어</a>
# 일번지 자갈치 산곰장어
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H601665" target="_blank">춘하추동밀면 해운대점</a>
# 춘하추동밀면 해운대점
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=D600810" target="_blank">듀스포레(douce foret)</a>
# 듀스포레(douce foret)
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H601546" target="_blank">막썰어파는횟집</a>
# 막썰어파는횟집
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=D600802" target="_blank">데블스도어 센텀시티몰점</a>
# 데블스도어 센텀시티몰점
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H601686" target="_blank">향유재</a>
# 향유재
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=T600102" target="_blank">누들팬</a>
# 누들팬
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H601651" target="_blank">기장촌집장어</a>
# 기장촌집장어
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H601671" target="_blank">용암할매횟집</a>
# 용암할매횟집
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H601515" target="_blank">수민이네</a>
# 수민이네
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=E600347" target="_blank">헬로우스시</a>
# 헬로우스시
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H601654" target="_blank">본가 해운대점</a>
# 본가 해운대점
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=J600532" target="_blank">미스터스시</a>
# 미스터스시
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=C600074" target="_blank">밍주</a>
# 밍주
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H601544" target="_blank">평안도족발</a>
# 평안도족발
# ------------------------------------
# <a href="/restaurant/onepage.asp?acode=H601542" target="_blank">뽀뽀통닭</a>
# 뽀뽀통닭
# ------------------------------------

# %%
listTypes=driver.find_elements(By.CLASS_NAME,'listType')
for i in listTypes:
    print(i.text)
# Out:
# 한식
# 분식
# 일식
# 분식
# 카페/주점
# 베이커리
# 한식
# 한식
# 한식
# 한식
# 한식
# 카페/주점
# 한식
# 카페/주점
# 한식
# 기타/세계
# 한식
# 한식
# 한식
# 뷔페
# 한식
# 일식
# 중식
# 한식
# 한식

# %%
from bs4 import BeautifulSoup

# %%
html=BeautifulSoup(driver.page_source,'html.parser')
aList=html.select('.restName > a')
for i in aList:
    print(a)
    print(a.text)
    print('-------------------------')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------
# <selenium.webdriver.remote.webelement.WebElement (session="03fc074f53c37c33b2b9e3e475a20ca7", element="f.09DCBD894A30C93F191A07BE4A27CE0E.d.60A7E174A9AF3F73E0373797567161B6.e.59")>
# 뽀뽀통닭
# -------------------------

# %%
murl="https://www.menupan.com/"
driver.get(murl)

# %%
#defaultHeader > form:nth-child(2) > div > div > fieldset > div > input[type=text]
myinput=driver.find_element(By.CSS_SELECTOR,".search_window [type='text']")
myinput.send_keys('중식')

# %%
myinput.click()

# %%
#defaultHeader > div.gnb > div.gnb_menu.floatR > ul.gnb_menu_ul > li.gnb_menu01 > a
st='#defaultHeader > div.gnb > div.gnb_menu.floatR > ul.gnb_menu_ul > li.gnb_menu01 > a'
my=driver.find_element(By.CSS_SELECTOR,st)
my.click()

st='body > table > tbody > tr:nth-child(3) > td > table > tbody > tr:nth-child(2) > td:nth-child(2) > table > tbody > tr > td:nth-child(1) > table > tbody > tr > td > table > tbody > tr:nth-child(1) > td:nth-child(2) > input'
my=driver.find_element(By.CSS_SELECTOR,st)
my.send_keys('dyd')

st='body > table > tbody > tr:nth-child(3) > td > table > tbody > tr:nth-child(2) > td:nth-child(2) > table > tbody > tr > td:nth-child(1) > table > tbody > tr > td > table > tbody > tr:nth-child(2) > td:nth-child(2) > input'
my=driver.find_element(By.CSS_SELECTOR,st)
my.send_keys(1234)

st='body > table > tbody > tr:nth-child(3) > td > table > tbody > tr:nth-child(2) > td:nth-child(2) > table > tbody > tr > td:nth-child(1) > table > tbody > tr > td > table > tbody > tr:nth-child(1) > td:nth-child(3) > a > img'
my=driver.find_element(By.CSS_SELECTOR,st)
my.click()

# %% [markdown]
# <h1> 네이버 쇼핑몰</h1>

# %%
nurl='https://shopping.naver.com/ns/home'
driver.get(nurl)
