# %%
# %pip install defusedxml
# Out:
# Requirement already satisfied: defusedxml in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (0.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import XMLOutputParser

# %% [markdown]
# ### XMLOutputParser

# %%
xml_out = XMLOutputParser()
format_instructions = xml_out.get_format_instructions()
print( format_instructions)
# Out:
# The output should be formatted as a XML file.
# 1. Output should conform to the tags below.
# 2. If tags are not given, make them on your own.
# 3. Remember to always open and close all the tags.
#
# As an example, for the tags ["foo", "bar", "baz"]:
# 1. String "<foo>
#    <bar>
#       <baz></baz>
#    </bar>
# </foo>" is a well-formatted instance of the schema.
# 2. String "<foo>
#    <bar>
#    </foo>" is a badly-formatted instance.
# 3. String "<foo>
#    <tag>
#    </tag>
# </foo>" is a badly-formatted instance.
#
# Here are the output tags:
# ```
# None
# ```

# %%
template = "10개의 팀을 보여줘 {subject}.\n{format_instructions}"
prompt = PromptTemplate(
    input_variables=["subject"],
    template=template,
    partial_variables={"format_instructions": format_instructions}
)
print( prompt.format( subject="한국의 야구팀은" ) )
# Out:
# 10개의 팀을 보여줘 한국의 야구팀은.
# The output should be formatted as a XML file.
# 1. Output should conform to the tags below.
# 2. If tags are not given, make them on your own.
# 3. Remember to always open and close all the tags.
#
# As an example, for the tags ["foo", "bar", "baz"]:
# 1. String "<foo>
#    <bar>
#       <baz></baz>
#    </bar>
# </foo>" is a well-formatted instance of the schema.
# 2. String "<foo>
#    <bar>
#    </foo>" is a badly-formatted instance.
# 3. String "<foo>
#    <tag>
#    </tag>
# </foo>" is a badly-formatted instance.
#
# Here are the output tags:
# ```
# None
# ```

# %%
gpt = ChatOpenAI( model_name="gpt-3.5-turbo", temperature=0)
rst = gpt.invoke( prompt.format(subject="한국의 야구팀은") )
print( rst.content )
# Out:
# <teams>
#    <team>Kia Tigers</team>
#    <team>Doosan Bears</team>
#    <team>LG Twins</team>
#    <team>NC Dinos</team>
#    <team>Samsung Lions</team>
#    <team>Kiwoom Heroes</team>
#    <team>KT Wiz</team>
#    <team>Hanwha Eagles</team>
#    <team>Lotte Giants</team>
#    <team>SSG Landers</team>
# </teams>

# %%
xml_out.parse(rst.content)  # XML 파싱
# Out:
# {'teams': [{'team': 'Kia Tigers'},
#   {'team': 'Doosan Bears'},
#   {'team': 'LG Twins'},
#   {'team': 'NC Dinos'},
#   {'team': 'Samsung Lions'},
#   {'team': 'Kiwoom Heroes'},
#   {'team': 'KT Wiz'},
#   {'team': 'Hanwha Eagles'},
#   {'team': 'Lotte Giants'},
#   {'team': 'SSG Landers'}]}

# %% [markdown]
# ### CommaSeparatedListOutputParser

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# %%
output_parser = CommaSeparatedListOutputParser()
format_instructions = output_parser.get_format_instructions()
print(format_instructions)
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %%
template ="List {number} {subject}. answer in Korean.\n{format_instructions}"
prompt = PromptTemplate( template=template,
    input_variables=["number", "subject"],
    partial_variables={"format_instructions": format_instructions}
)

print( prompt.format( number=4, subject="공포 영화" ) )
# Out:
# List 4 공포 영화. answer in Korean.
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %%
gpt = ChatOpenAI( model_name="gpt-3.5-turbo", temperature=0)
# rst = gpt.invoke( prompt.format( number=4, subject="공포 영화" )  )
rst = gpt.invoke( prompt.format( number=10, subject="한국의 야구팀" )  )
print( rst.content )
# Out:
# 두산 베어스, 롯데 자이언츠, KIA 타이거즈, 삼성 라이온즈, LG 트윈스, NC 다이노스, 키움 히어로즈, 한화 이글스, SK 와이번스, KT 위즈

# %% [markdown]
# ### DatetimeOutputParser

# %%
from langchain_core.output_parsers import DatetimeOutputParser
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from langchain_core.output_parsers import DatetimeOutputParser
#
# ImportError: cannot import name 'DatetimeOutputParser' from 'langchain_core.output_parsers' (c:\Users\Dell5371\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_core\output_parsers\__init__.py)

# %%
output_parser = DatetimeOutputParser()
format_instructions = output_parser.get_format_instructions()
print(format_instructions)
# Out:
# Write a datetime string that matches the following pattern: '%Y-%m-%dT%H:%M:%S.%fZ'.
#
# Examples: 1277-12-03T21:30:58.890175Z, 1663-05-16T18:27:19.754204Z, 0573-12-19T10:32:39.671425Z
#
# Return ONLY this string, no other words!

# %%
template = """
Answer the users question:
{question}

{format_instructions}
"""
prompt = PromptTemplate(template=template,
    input_variables=["question"],
    partial_variables={"format_instructions": format_instructions}
)

print(prompt.format(question="비트코인은 언제 개발되었나요?"))
# Out:
# Answer the users question:
# 비트코인은 언제 개발되었나요?
#
# Write a datetime string that matches the following pattern: '%Y-%m-%dT%H:%M:%S.%fZ'.
#
# Examples: 1277-12-03T21:30:58.890175Z, 1663-05-16T18:27:19.754204Z, 0573-12-19T10:32:39.671425Z
#
# Return ONLY this string, no other words!

# %%
gpt = ChatOpenAI( model_name="gpt-3.5-turbo", temperature=0)
rst = gpt.invoke( prompt.format(question="비트코인은 언제 개발되었나요?") )
print( rst.content )
# Out:
# 2009-01-03T18:15:05.000000Z

# %%
# 퀴즈 딥러닝은 언제 개발되었나요?

# %% [markdown]
# ### JsonOutputParser

# %%
from langchain_core.output_parsers import JsonOutputParser

# %%
parser = JsonOutputParser()
format_instructions = parser.get_format_instructions()
print(format_instructions)
# Out:
# Return a JSON object.

# %%
template = "당신의 이름은 {name}이고, 나이는 {age}을 다음형식으로 출력:\n\n{format_instructions}"
prompt = PromptTemplate(
    input_variables=["name", "age"],
    template=template,
    partial_variables={"format_instructions": format_instructions}
)
print(prompt.format(name="홍길동", age=30))
# Out:
# 당신의 이름은 홍길동이고, 나이는 30을 다음형식으로 출력:
#
# Return a JSON object.

# %%
gpt = ChatOpenAI( model_name="gpt-3.5-turbo", temperature=0)
rst = gpt.invoke( prompt.format(name="홍길동", age=30) )
print( rst.content )
# Out:
# {
#     "name": "홍길동",
#     "age": 30
# }

# %%
parser.parse(rst.content)  # JSON 파싱
# Out:
# {'name': '홍길동', 'age': 30}

# %%
from pydantic import BaseModel, Field

# %%
class Country(BaseModel):
    continet: str = Field(description="사용자가 물어본 나라가 속한 대륙")
    population: int = Field(description="사용자가 물어본 나라의 인구")  

parser = JsonOutputParser(pydantic_object=Country)
format_instructions = parser.get_format_instructions()
print(format_instructions)
# Out:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"properties": {"continet": {"description": "사용자가 물어본 나라가 속한 대륙", "title": "Continet", "type": "string"}, "population": {"description": "사용자가 물어본 나라의 인구", "title": "Population", "type": "integer"}}, "required": ["continet", "population"]}
# ```

# %%
template = "answer the question.\n{question}\n\n{format_instructions}"
prompt = PromptTemplate(   template=template,
    input_variables=["question"],   
    partial_variables={"format_instructions": format_instructions}
)

print( prompt.format( question="아르헨티나는 어떤 나라야?" ) )
# Out:
# answer the question.
# 아르헨티나는 어떤 나라야?
#
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# {"properties": {"continet": {"description": "사용자가 물어본 나라가 속한 대륙", "title": "Continet", "type": "string"}, "population": {"description": "사용자가 물어본 나라의 인구", "title": "Population", "type": "integer"}}, "required": ["continet", "population"]}
# ```

# %%
gpt = ChatOpenAI( model_name="gpt-3.5-turbo", temperature=0)
rst = gpt.invoke( prompt.format( question="아르헨티나는 어떤 나라야?" ) )
print( rst.content )
# Out:
# {
#   "continet": "남아메리카",
#   "population": 44938712
# }
