# %%
from openai import OpenAI
import openai
import os

api_key = os.getenv('OPENAI_API_KEY')
openai.api_key = api_key

# %%
client = OpenAI()
response = client.images.edit( model="dall-e-2",
                   image= open( "image/sunlit.png",'rb'),
                    mask= open( "image/mask3.png",'rb'),
                    prompt="A sunlit indoor lounge area with a pool containing a fish",
                    n=2,
                    size="1024x1024" )

print( response.data[0].url)
print( response.data[1].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-EJG5IHw3Ylzybe0eBra5SppJ/user-lRV2xpCXqw15d7PIwkS4eDbV/img-70gGtNZry8iJasGEefLkBXWn.png?st=2025-07-01T11%3A27%3A47Z&se=2025-07-01T13%3A27%3A47Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-30T19%3A33%3A25Z&ske=2025-07-01T19%3A33%3A25Z&sks=b&skv=2024-08-04&sig=dnih0/l1q4/MC6wB9oji1quaHWND0oH5bdc5VeUSmKc%3D
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-EJG5IHw3Ylzybe0eBra5SppJ/user-lRV2xpCXqw15d7PIwkS4eDbV/img-8oOVQpAzvcI5UoFNCyRnUlDA.png?st=2025-07-01T11%3A27%3A47Z&se=2025-07-01T13%3A27%3A47Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=8b33a531-2df9-46a3-bc02-d4b1430a422c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-06-30T19%3A33%3A25Z&ske=2025-07-01T19%3A33%3A25Z&sks=b&skv=2024-08-04&sig=fgczNyFS2lIqyeBwj6UiHwfBxO595WiLbmJe2shpM1s%3D

# %% [markdown]
# ### 음성녹음 wav 파일로 저장

# %%
# %pip install sounddevice
# %pip install scipy
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: sounddevice in c:\python310\lib\site-packages (0.5.2)
# Requirement already satisfied: CFFI>=1.0 in c:\python310\lib\site-packages (from sounddevice) (1.17.1)
# Requirement already satisfied: pycparser in c:\python310\lib\site-packages (from CFFI>=1.0->sounddevice) (2.22)
# WARNING: Ignoring invalid distribution -lotly (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\python310\lib\site-packages)
# Requirement already satisfied: scipy in c:\python310\lib\site-packages (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\python310\lib\site-packages (from scipy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -lotly (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\python310\lib\site-packages)

# %%
import sounddevice as sd
from scipy.io.wavfile import write

try:
    fs = 16000 # 샘플링속도
    duration = 5 # 녹음시간 5
    print( '녹음시작')
    audio_data = sd.rec( int(duration*fs) , samplerate=fs, channels=1 )
    sd.wait()
    print( '녹음완료')
    write( 'rec.wav', fs, audio_data)
except Exception as err:
    print( '에러발생', err)
