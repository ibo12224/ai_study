# %% [markdown]
# **Streamlit(스트림릿)**은 데이터 사이언티스트와 머신러닝 엔지니어가 **Python 코드만으로 빠르고 아름다운 웹 애플리케이션을 만들 수 있게 해주는 오픈소스 프레임워크**입니다.
#
# HTML, CSS, JavaScript 같은 프론트엔드 지식이 없어도 데이터 분석 결과를 시각화하거나 모델 데모 페이지를 구축하는 데 최적화되어 있습니다.
#
# ---
#
# ## 1. Streamlit의 주요 특징
#
# * **파이썬 전용:** 백엔드와 프론트엔드를 구분할 필요 없이 오직 Python으로만 작성합니다.
# * **빠른 개발 속도:** 위젯(버튼, 슬라이더 등)을 변수처럼 선언하여 즉시 UI를 구성할 수 있습니다.
# * **실시간 반영 (Hot Reloading):** 코드를 수정하고 저장하면 브라우저에 즉시 업데이트됩니다.
# * **강력한 시각화 지원:** Matplotlib, Plotly, Altair, Pandas 등 주요 데이터 라이브러리와 완벽하게 호환됩니다.
# * **배포 용이성:** 'Streamlit Community Cloud'를 통해 GitHub 저장소와 연결하면 클릭 몇 번으로 무료 배포가 가능합니다.
#
# ---
#
# ## 2. 기본 구성 요소 (핵심 함수)
#
# 스트림릿에서 자주 사용하는 기능들은 다음과 같습니다.
#
# | 구분 | 함수 예시 | 용도 |
# | --- | --- | --- |
# | **텍스트** | `st.title()`, `st.header()`, `st.write()` | 제목, 본문, 마크다운 출력 |
# | **데이터** | `st.dataframe()`, `st.table()` | 인터랙티브 표 또는 정적 표 출력 |
# | **차트** | `st.line_chart()`, `st.pyplot()` | 선 그래프 및 다양한 시각화 도구 출력 |
# | **입력 위젯** | `st.button()`, `st.slider()`, `st.text_input()` | 사용자로부터 입력을 받는 도구 |
# | **레이아웃** | `st.sidebar`, `st.columns()` | 사이드바 생성 및 화면 분할 |
#
# ---
#
#
# ## 3. 장점과 단점
#
# ### 장점
#
# * 학습 곡선이 매우 낮음 (파이썬만 알면 바로 시작 가능)
# * 프로토타입 제작에 압도적으로 유리함
# * 디자인이 기본적으로 깔끔하고 현대적임
#
# ### 단점
#
# * 복잡하고 고도로 커스터마이징된 UI 구현은 어려움
# * 페이지가 상호작용할 때마다 코드 전체가 처음부터 다시 실행됨 (캐싱(`@st.cache_data`)으로 보완 가능)

# %% [markdown]
# ### streamlit
# - webserver
# - 함수기반 페이지구성
# - 풍부한 plugin
# - 반드시 py 파일로 작성
# - 서버구동: streamlit run 파일명.py

# %%
# %pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.52.2-py3-none-any.whl.metadata (9.8 kB)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<7,>=4.0 (from streamlit)
#   Downloading cachetools-6.2.4-py3-none-any.whl.metadata (5.6 kB)
# Collecting click<9,>=7.0 (from streamlit)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.2.6)
# Requirement already satisfied: packaging>=20 in c:\users\dell5371\appdata\roaming\python\python310\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (6.33.2)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-22.0.0-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.32.5)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\dell5371\appdata\roaming\python\python310\site-packages (from streamlit) (4.15.0)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.46-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\dell5371\appdata\roaming\python\python310\site-packages (from streamlit) (6.5.2)
# Requirement already satisfied: jinja2 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.13.0)
# Requirement already satisfied: colorama in c:\users\dell5371\appdata\roaming\python\python310\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell5371\appdata\roaming\python\python310\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dell5371\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell5371\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.52.2-py3-none-any.whl (9.0 MB)
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    ---------------------------------------- 9.0/9.0 MB 56.2 MB/s  0:00:00
# Downloading altair-6.0.0-py3-none-any.whl (795 kB)
#    ---------------------------------------- 0.0/795.4 kB ? eta -:--:--
#    ---------------------------------------- 795.4/795.4 kB ?  0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-6.2.4-py3-none-any.whl (11 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading gitpython-3.1.46-py3-none-any.whl (208 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------------------------------------- 6.9/6.9 MB 42.6 MB/s  0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading pyarrow-22.0.0-cp310-cp310-win_amd64.whl (28.1 MB)
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    ------------------- -------------------- 13.9/28.1 MB 72.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 21.0/28.1 MB 49.1 MB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 48.2 MB/s  0:00:00
# Installing collected packages: watchdog, toml, tenacity, smmap, pyarrow, click, cachetools, blinker, pydeck, gitdb, gitpython, altair, streamlit
#
#    ----------------------------------------  0/13 [watchdog]
#    ----------------------------------------  0/13 [watchdog]
#    ----------------------------------------  0/13 [watchdog]
#    ----------------------------------------  0/13 [watchdog]
#    ----------------------------------------  0/13 [watchdog]
#    --- ------------------------------------  1/13 [toml]
#    ------ ---------------------------------  2/13 [tenacity]
#    ------ ---------------------------------  2/13 [tenacity]
#    --------- ------------------------------  3/13 [smmap]
#    --------- ------------------------------  3/13 [smmap]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    ------------ ---------------------------  4/13 [pyarrow]
#    --------------- ------------------------  5/13 [click]
#    --------------- ------------------------  5/13 [click]
#    --------------- ------------------------  5/13 [click]
#    ------------------ ---------------------  6/13 [cachetools]
#    --------------------- ------------------  7/13 [blinker]
#    ------------------------ ---------------  8/13 [pydeck]
#    ------------------------ ---------------  8/13 [pydeck]
#    ------------------------ ---------------  8/13 [pydeck]
#    ------------------------ ---------------  8/13 [pydeck]
#    ------------------------ ---------------  8/13 [pydeck]
#    --------------------------- ------------  9/13 [gitdb]
#    --------------------------- ------------  9/13 [gitdb]
#    --------------------------- ------------  9/13 [gitdb]
#    --------------------------- ------------  9/13 [gitdb]
#    ------------------------------ --------- 10/13 [gitpython]
#    ------------------------------ --------- 10/13 [gitpython]
#    ------------------------------ --------- 10/13 [gitpython]
#    ------------------------------ --------- 10/13 [gitpython]
#    ------------------------------ --------- 10/13 [gitpython]
#    ------------------------------ --------- 10/13 [gitpython]
#    ------------------------------ --------- 10/13 [gitpython]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    --------------------------------- ------ 11/13 [altair]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ------------------------------------ --- 12/13 [streamlit]
#    ---------------------------------------- 13/13 [streamlit]
#
# Successfully installed altair-6.0.0 blinker-1.9.0 cachetools-6.2.4 click-8.3.1 gitdb-4.0.12 gitpython-3.1.46 pyarrow-22.0.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.52.2 tenacity-9.1.2 toml-0.10.2 watchdog-6.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
st.title('hello streamlit')

# %%
import streamlit as st
st.title('hello streamlit')
st.header('header')
st.subheader('sub header')
st.text('hello text')
st.write('hello write')
st.image('image/cat.jpg')

# %%
import streamlit as st

st.markdown('마크다운')
st.markdown('# 제목1')
st.markdown('## 제목2')
st.markdown('### 제목3') # 6개까지
st.markdown('*이태릭*')
st.markdown('이 택스트는 **강조** 됩니다.')
st.markdown( '<span style="color:red">빨간색 글자</span>', unsafe_allow_html=True)
st.markdown('[네이버](http://www.naver.com)')
st.markdown( '- 항목' )
st.markdown( '- 사과\n- 딸기\n- 포도' )
st.markdown( """
```python
def hello():
    print('hello test')
""")
st.markdown('---')
st.markdown("""
| 이름 | 나이 |
|------|------|
| 홍길동 | 30 |
| 김영희 | 25 |
""")

# %%
import streamlit as st

st.title('유튜브 보라카이여행')
st.markdown('---')
st.video('https://youtu.be/JCF-hP4V24I')

# %%
import streamlit as st

with st.form('myform'):
    name = st.text_input('이름')
    age = st.number_input('나이',value=0, step=1, min_value=0, max_value=100)
    birth = st.date_input('생일')
    submit = st.form_submit_button('확인')
    if submit:
        s = f'이름:{name} 나이:{age} 생일:{birth}'
        st.write( s )

st.write('테스트')

# %%
import streamlit as st
with st.form('myform'):
    num1 = st.number_input('숫자1', value=0, step=1)
    num2 = st.number_input('숫자2', value=0, step=1)
    submit = st.form_submit_button('계산')
    if submit:
        hap = num1 + num2
        st.write(f'합: {hap}')

# %%
import streamlit as st

with st.form('myform'):
    name = st.text_input('', placeholder="이름을 입력")
    age = st.number_input('나이',value=0, step=1, min_value=0, max_value=20)
    birth = st.date_input('생일')
    submit = st.form_submit_button('확인')
    if submit:
        s = f'이름:{name} 나이:{age} 생일:{birth}'
        st.write( s )

st.write('테스트')

# %%
import streamlit as st

with st.form('myform'):
    myin = st.text_input('입력')
    submit = st.form_submit_button('확인')
    if submit:
        s = f'입력:{myin}'
        st.write( s )

# %%
import streamlit as st
from openai import OpenAI
import openai
import os

# client  = OpenAI()
if "client" not in st.session_state:
    api_key = os.getenv('OPENAI_API_KEY')
    openai.api_key = api_key
    st.session_state['client']  = OpenAI()

def GPT(prompt):
    response = st.session_state['client'].chat.completions.create(
        model='gpt-3.5-turbo', 
        messages=[{'role':'user','content':prompt}]
    )
    return response.choices[0].message.content

st.title( '🤖 GPT 챗봇')
st.markdown('---')

# 안에 영역 생성
with st.form('myform'): 
    prompt = st.text_input('👩‍🦰프롬프트', placeholder="입력")
    submit = st.form_submit_button('확인')
    if submit:
        with st.spinner():
            rst = GPT(prompt)
            s = f'🤖 GPT 답변 : {rst}'
            st.write(s)

# %% [markdown]
# ### 모듈분리

# %% [markdown]
# ## main.py

# %%
from gptmodule import st, GPT


st.title( '🤖 GPT 챗봇')
st.markdown('---')

# 안에 영역 생성
with st.form('myform'): 
    prompt = st.text_input('👩‍🦰프롬프트', placeholder="입력")
    submit = st.form_submit_button('확인')
    if submit:
        with st.spinner():
            rst = GPT(prompt)
            s = f'🤖 GPT 답변 : {rst}'
            st.write(s)

# %% [markdown]
# ### gptmodule.py

# %%
import streamlit as st
from openai import OpenAI
import openai
import os

api_key = os.getenv('OPENAI_API_KEY')
openai.api_key = api_key
client  = OpenAI()

def GPT(prompt):
    response = client.chat.completions.create(
        model='gpt-3.5-turbo', 
        messages=[{'role':'user','content':prompt}]
    )
    return response.choices[0].message.content
