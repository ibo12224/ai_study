# %%
import os
import openai
from openai import OpenAI
apiKey = os.getenv('OPENAI_API_KEY')
openai.api_key = apiKey

# %% [markdown]
# - system role:역할부여
# - user role:사용자질문( 프롬프트)
# - assistant role: gpt 답변(컴플리션)

# %%
client = OpenAI()

completion = client.chat.completions.create(model="gpt-3.5-turbo",
    messages=[
        {'role':'system', 'content':'You are a helpful teacher'},
        {'role':'user',
            'content':'Are ther other measure than time complexity for an algorithm?'},
        {'role':'assistant',
            'content':'Yes, there are other measures besides time complexity\
            for an algorithm, such as space complexity.' },
        {'role':'user','content':'What is it?'}] )

print( completion.choices[0].message.content)
# Out:
# Space complexity, also known as memory complexity, measures the amount of memory, or space, an algorithm uses as a function of the input size. It helps us understand how efficiently an algorithm utilizes memory resources. Just like time complexity, space complexity is also expressed using Big O notation to describe the upper bound of the space used by an algorithm as the input size grows.
