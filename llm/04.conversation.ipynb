# %%
import os
import openai
from openai import OpenAI
apiKey = os.getenv('OPENAI_API_KEY')
openai.api_key = apiKey

# %% [markdown]
# conv_history=[{'role':'system','content':'You are a helpful teacher' },
#     {'role':'user','content':'인공지능에 대해 간단히 알려줄래'},
#     {'role':'assistant','content':'인공지능에 대한답변'},
#     {'role':'user','content':'더 간단하게 요약해줘'},
#     ]

# %%
client = OpenAI()
1
conv_history=[{'role':'system','content':'You are a helpful teacher' }]
conv_history.append( {'role':'user','content':'인공지능에 대해 간단히 알려줄래'})

completion = client.chat.completions.create(model='gpt-3.5-turbo',
    messages=conv_history )

chatReply = completion.choices[0].message.content
print( chatReply )
conv_history.append( {'role':'assistant','content':chatReply} )
conv_history.append({'role':'user', 'content':'더 간단하게 요약해줘'})

completion = client.chat.completions.create(model='gpt-3.5-turbo',
    messages=conv_history )
print('============')
print( completion.choices[0].message.content )
# Out:
# 인공지능은 인간의 학습, 추론, 판단, 문제해결 등과 같은 지적 능력을 컴퓨터 시스템을 통해 구현하는 기술을 말합니다. 즉, 인공지능은 컴퓨터가 사람처럼 학습하고 일상적인 작업을 수행할 수 있도록 하는 기술이며, 이를 위해 기계학습, 심층학습, 자연어 처리 등 다양한 기술이 활용됩니다. 인공지능은 이미 우리 주변에서 많은 형태로 활용되고 있으며, 앞으로 더욱 다양한 분야에서의 응용이 기대됩니다.
# ============
# 인공지능은 컴퓨터가 사람처럼 학습하고 문제를 해결할 수 있는 기술이에요.

# %%
client = OpenAI()
conv_history=[{'role':'system','content':'You are a helpful teacher' }]

def conv_with_gpt( user_input):
    conv_history.append( {'role':'user','content':user_input})    
    completion = client.chat.completions.create(model='gpt-3.5-turbo',
        messages=conv_history )
    
    chatReply = completion.choices[0].message.content
    conv_history.append( {'role':'assistant','content':chatReply} )
    return chatReply

response = conv_with_gpt( '인공지능에 대해 알려줄래')
print( response)
print('------------')
response = conv_with_gpt( '더 간단히 요약해줘')
print( response)
# Out:
# 물론이죠! 인공지능은 컴퓨터 프로그램이 인간의 지능을 모방하거나 시뮬레이션하는 기술을 의미합니다. 이를 통해 컴퓨터 시스템이 학습, 추론, 자동화 작업 등을 수행할 수 있습니다. 인공지능은 기계학습, 딥러닝, 자연어 처리, 컴퓨터 비전 등 여러 분야로 나뉘어지며, 현재는 많은 산업 분야에서 활용되고 있습니다. 유용한 정보였나요?더 궁금한 점이 있으시면 더 자세히 알려드릴 수 있습니다.
# ------------
# 인공지능은 컴퓨터가 사람의 지능을 모방하는 기술이에요. 컴퓨터가 학습하고 추론하여 다양한 작업을 자동으로 수행할 수 있어요. 현재 많은 산업 분야에서 사용되고 있어요.
